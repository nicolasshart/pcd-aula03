# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolasshart/pcd-aula03/blob/main/aula_github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git --version
# !git config --global user.name "nicolasshart"
# !git config --global user.email "nicolas.seibt.h@gmail.com"
# !git config --global init.defaultBranch main
# !git config --global --list
# Out:
# git version 2.34.1
# user.name=nicolasshart
# user.email=nicolas.seibt.h@gmail.com
# init.defaultbranch=main

# %%
# !git clone https://github.com/nicolasshart/pcd-aula03.git
# %cd pcd-aula03
# !ls
# !git status
# !git remote -v
# Out:
# Cloning into 'pcd-aula03'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
# /content/pcd-aula03
# README.md
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# origin	https://github.com/nicolasshart/pcd-aula03.git (fetch)
# origin	https://github.com/nicolasshart/pcd-aula03.git (push)

# %%
# %%writefile README.md
# # PCD - Aula 03
# Arquivos da Aula 03: Colab, GitHub e Git.
# ## Autor
# Nícolas Hartmann
# Out:
# Overwriting README.md

# %%
# !git add README.md
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   README.md

# %%
# !git commit -m "Update class README"
# Out:
# [main 72ec661] Update class README
#  1 file changed, 4 insertions(+), 1 deletion(-)

# %%
# !git push origin main
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 330 bytes | 330.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/nicolasshart/pcd-aula03.git
#    0fa605b..72ec661  main -> main

# %%
# !apt-get -qq update
# !apt-get -qq install gh
# !GH_PROMPT_DISABLED=1 gh auth login --hostname github.com --git-protocol https --web
# !gh auth setup-git
# !gh auth status
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
#
# ! First copy your one-time code: 3AEA-6174
# Open this URL to continue in your web browser: https://github.com/login/device
# ✓ Authentication complete.
# - gh config set -h github.com git_protocol https
# ✓ Configured git protocol
# ! Authentication credentials saved in plain text
# ✓ Logged in as nicolasshart
# github.com
#   ✓ Logged in to github.com account nicolasshart (/root/.config/gh/hosts.yml)
#   - Active account: true
#   - Git operations protocol: https
#   - Token: gho_************************************
#   - Token scopes: 'gist', 'read:org', 'repo'

# %%
# !git pull origin main
# Out:
# From https://github.com/nicolasshart/pcd-aula03
#  * branch            main       -> FETCH_HEAD
# Already up to date.
